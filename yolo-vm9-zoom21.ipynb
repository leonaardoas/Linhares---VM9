# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install --upgrade pip

# %%
# !pip install ultralytics

# %%
import os
import glob
import pandas as pd
import re
import math
from ultralytics import YOLO
import cv2
from PIL import Image
import matplotlib.pyplot as plt

# %%
# Carrega o modelo YOLO
best_model = YOLO('/kaggle/input/bestmodel/best.pt')

# %%
# Função para converter tile em latitude e longitude
def tile_to_latlon(zoom, x, y):
    """Converte coordenadas de tile (z, x, y) em latitude e longitude."""
    n = 2.0 ** zoom
    lon_deg = x / n * 360.0 - 180.0
    lat_rad = math.atan(math.sinh(math.pi * (1 - 2 * y / n)))
    lat_deg = math.degrees(lat_rad)
    return lat_deg, lon_deg

# Função para extrair z, x, y do caminho da imagem
def extract_tile_info(image_path):
    """Extrai z, x, y do caminho da imagem e do nome do arquivo."""
    # Este padrão assume que os últimos três componentes numéricos são z, x, e y (nome do arquivo sem extensão).
    pattern = r'/(\d+)/(\d+)/([^/]+)\.png$' # Mantido como no original
    match = re.search(pattern, image_path)
    if match:
        # O terceiro grupo (nome do arquivo) é y.
        z_str, x_str, y_filename_str = match.groups()
        z = int(z_str)
        x = int(x_str)
        y = int(y_filename_str) # O nome do arquivo sem .png é o Y do tile
        return z, x, y
    else:
        raise ValueError(f"Formato de caminho inválido ou não مطابق com o padrão Z/X/Y.png: {image_path}")

# Tamanho do tile em pixels (assumindo 256x256)
tile_size = 256

# --- INÍCIO DAS MODIFICAÇÕES PRINCIPAIS ---

# Define o diretório base que contém suas pastas 
base_dir_processing = '/kaggle/input/ortofotosz21/20' 

# Nome do arquivo CSV de saída e frequência de salvamento
output_csv = '/kaggle/working/zoom20.csv'
save_every_n_folders = 100  # Salvar a cada 50 pastas X processadas

# Lista para acumular dados antes de salvar no CSV
all_data_for_csv = []
processed_x_folders_count = 0 # Contador para as pastas X processadas

print(f"Procurando subdiretórios (pastas X) em: {base_dir_processing}")

# Lista todas as subpastas (pastas X) diretamente dentro de base_dir_processing
try:
    # Garante que estamos listando apenas diretórios
    x_folders = [f.path for f in os.scandir(base_dir_processing) if f.is_dir()]
except FileNotFoundError:
    print(f"Erro Crítico: Diretório base de processamento '{base_dir_processing}' não encontrado. Verifique o caminho.")
    x_folders = [] # Define como lista vazia para evitar mais erros

if not x_folders:
    print(f"Nenhuma subpasta (pasta X) encontrada em '{base_dir_processing}'. Verifique o caminho e a estrutura de pastas.")
    # Considere adicionar exit() se não houver pastas para processar
else:
    print(f"Encontradas {len(x_folders)} subpastas (pastas X) para processar.")

total_x_folders = len(x_folders)

# Itera sobre cada pasta X
for folder_index, x_folder_path in enumerate(x_folders):
    current_folder_num = folder_index + 1
    print(f"\nProcessando pasta X {current_folder_num}/{total_x_folders}: {x_folder_path}")

    # Lista todas as imagens PNG dentro da pasta X atual
    image_paths_in_x_folder = glob.glob(os.path.join(x_folder_path, '*.png'))

    if not image_paths_in_x_folder:
        print(f"  Nenhuma imagem .png encontrada em '{x_folder_path}'. Pulando para a próxima pasta X.")
        # Continua para a próxima pasta X, mas ainda conta esta pasta para o salvamento periódico
    else:
        print(f"  Encontradas {len(image_paths_in_x_folder)} imagens PNG para processar em '{x_folder_path}'.")

    # Itera sobre todas as imagens na pasta X atual
    for image_path in image_paths_in_x_folder:
        try:
            # Realiza a predição
            results = best_model.predict(image_path, conf=0.45, imgsz=256, verbose=False) # verbose=False para menos output

            # Extrai z, x, y do caminho da imagem
            # Note que 'extract_tile_info' agora é chamado aqui, dentro do try-except
            z, x, y = extract_tile_info(image_path)
            tile_lat, tile_lon = tile_to_latlon(z, x, y)

            if not results or not results[0].boxes or len(results[0].boxes) == 0:
                # print(f"    Nenhuma detecção para a imagem {image_path}.") # Descomente se precisar deste log
                continue # Pula para a próxima imagem se não houver detecções

            # Extrai as coordenadas das caixas delimitadoras
            for i, result_box in enumerate(results[0].boxes):
                box_coords = result_box.xyxy[0].cpu().numpy()
                x_min, y_min, x_max, y_max = box_coords
                class_id = int(result_box.cls.cpu().numpy().item())
                class_name = results[0].names[class_id]

                vertices = [
                    (x_min, y_min), (x_max, y_min),
                    (x_min, y_max), (x_max, y_max)
                ]
                vertex_coords = []
                for vx, vy in vertices:
                    x_offset = vx / tile_size
                    y_offset = vy / tile_size
                    x_adjusted = x + x_offset
                    y_adjusted = y + y_offset
                    v_lat, v_lon = tile_to_latlon(z, x_adjusted, y_adjusted)
                    vertex_coords.append((v_lat, v_lon))

                (top_left_lat, top_left_lon), (top_right_lat, top_right_lon), \
                (bottom_left_lat, bottom_left_lon), (bottom_right_lat, bottom_right_lon) = vertex_coords

                all_data_for_csv.append({
                    'image_path': image_path,
                    'object_id': i + 1,
                    'class': class_name,
                    'x_min': x_min, 'y_min': y_min, 'x_max': x_max, 'y_max': y_max,
                    'tile_latitude': tile_lat, 'tile_longitude': tile_lon,
                    'top_left_latitude': top_left_lat, 'top_left_longitude': top_left_lon,
                    'top_right_latitude': top_right_lat, 'top_right_longitude': top_right_lon,
                    'bottom_left_latitude': bottom_left_lat, 'bottom_left_longitude': bottom_left_lon,
                    'bottom_right_latitude': bottom_right_lat, 'bottom_right_longitude': bottom_right_lon
                })
        except ValueError as e_tile_info: # Erro do extract_tile_info
            print(f"    Erro ao extrair informações do tile de '{image_path}': {e_tile_info}. Pulando esta imagem.")
            continue
        except Exception as e_predict: # Outros erros (ex: YOLO, processamento de resultados)
            print(f"    Erro ao processar a imagem '{image_path}': {e_predict}. Pulando esta imagem.")
            continue
    # Fim do loop de imagens na pasta X atual

    processed_x_folders_count += 1

    # Salva a cada 'save_every_n_folders' OU se for a última pasta X E houver dados para salvar
    if (processed_x_folders_count % save_every_n_folders == 0) or (current_folder_num == total_x_folders):
        if all_data_for_csv: # Só salva se houver dados acumulados
            print(f"  Salvando dados de {len(all_data_for_csv)} detecções no CSV (total de pastas X processadas: {processed_x_folders_count})...")
            df_to_save = pd.DataFrame(all_data_for_csv)
            
            # Verifica se o arquivo CSV já existe para decidir sobre o cabeçalho
            file_exists = os.path.exists(output_csv)
            df_to_save.to_csv(output_csv, mode='a', header=not file_exists, index=False)
            
            print(f"  Dados apensados em: {output_csv}")
            all_data_for_csv = [] # Limpa a lista para liberar memória para o próximo lote
        elif (current_folder_num == total_x_folders):
             print(f"  Nenhum dado novo para salvar no CSV ao final do processamento das pastas X.")
        else:
            print(f"  Nenhum dado novo para salvar no CSV neste lote de {save_every_n_folders} pastas X (total processadas: {processed_x_folders_count}).")

# --- FIM DAS MODIFICAÇÕES PRINCIPAIS ---

print("\nProcessamento de todas as pastas X concluído.")
if os.path.exists(output_csv):
    print(f"O arquivo CSV final está salvo em: {output_csv}")
else:
    print("Nenhum dado foi salvo no CSV durante a execução.")
# Out:
# Procurando subdiretórios (pastas X) em: /kaggle/input/ortofotosz21/20
# Encontradas 254 subpastas (pastas X) para processar.
#
# Processando pasta X 1/254: /kaggle/input/ortofotosz21/20/407657
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407657'.
#
# Processando pasta X 2/254: /kaggle/input/ortofotosz21/20/407599
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407599'.
#
# Processando pasta X 3/254: /kaggle/input/ortofotosz21/20/407546
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407546'.
#
# Processando pasta X 4/254: /kaggle/input/ortofotosz21/20/407765
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407765'.
#
# Processando pasta X 5/254: /kaggle/input/ortofotosz21/20/407552
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407552'.
#
# Processando pasta X 6/254: /kaggle/input/ortofotosz21/20/407668
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407668'.
#
# Processando pasta X 7/254: /kaggle/input/ortofotosz21/20/407600
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407600'.
#
# Processando pasta X 8/254: /kaggle/input/ortofotosz21/20/407610
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407610'.
#
# Processando pasta X 9/254: /kaggle/input/ortofotosz21/20/407643
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407643'.
#
# Processando pasta X 10/254: /kaggle/input/ortofotosz21/20/407702
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407702'.
#
# Processando pasta X 11/254: /kaggle/input/ortofotosz21/20/407677
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407677'.
#
# Processando pasta X 12/254: /kaggle/input/ortofotosz21/20/407772
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407772'.
#
# Processando pasta X 13/254: /kaggle/input/ortofotosz21/20/407558
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407558'.
#
# Processando pasta X 14/254: /kaggle/input/ortofotosz21/20/407545
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407545'.
#
# Processando pasta X 15/254: /kaggle/input/ortofotosz21/20/407623
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407623'.
#
# Processando pasta X 16/254: /kaggle/input/ortofotosz21/20/407656
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407656'.
#
# Processando pasta X 17/254: /kaggle/input/ortofotosz21/20/407740
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407740'.
#
# Processando pasta X 18/254: /kaggle/input/ortofotosz21/20/407755
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407755'.
#
# Processando pasta X 19/254: /kaggle/input/ortofotosz21/20/407620
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407620'.
#
# Processando pasta X 20/254: /kaggle/input/ortofotosz21/20/407617
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407617'.
#
# Processando pasta X 21/254: /kaggle/input/ortofotosz21/20/407671
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407671'.
#
# Processando pasta X 22/254: /kaggle/input/ortofotosz21/20/407710
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407710'.
#
# Processando pasta X 23/254: /kaggle/input/ortofotosz21/20/407761
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407761'.
#
# Processando pasta X 24/254: /kaggle/input/ortofotosz21/20/407538
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407538'.
#
# Processando pasta X 25/254: /kaggle/input/ortofotosz21/20/407563
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407563'.
#
# Processando pasta X 26/254: /kaggle/input/ortofotosz21/20/407662
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407662'.
#
# Processando pasta X 27/254: /kaggle/input/ortofotosz21/20/407667
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407667'.
#
# Processando pasta X 28/254: /kaggle/input/ortofotosz21/20/407749
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407749'.
#
# Processando pasta X 29/254: /kaggle/input/ortofotosz21/20/407744
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407744'.
#
# Processando pasta X 30/254: /kaggle/input/ortofotosz21/20/407665
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407665'.
#
# Processando pasta X 31/254: /kaggle/input/ortofotosz21/20/407762
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407762'.
#
# Processando pasta X 32/254: /kaggle/input/ortofotosz21/20/407527
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407527'.
#
# Processando pasta X 33/254: /kaggle/input/ortofotosz21/20/407526
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407526'.
#
# Processando pasta X 34/254: /kaggle/input/ortofotosz21/20/407767
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407767'.
#
# Processando pasta X 35/254: /kaggle/input/ortofotosz21/20/407630
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407630'.
#
# Processando pasta X 36/254: /kaggle/input/ortofotosz21/20/407544
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407544'.
#
# Processando pasta X 37/254: /kaggle/input/ortofotosz21/20/407641
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407641'.
#
# Processando pasta X 38/254: /kaggle/input/ortofotosz21/20/407651
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407651'.
#
# Processando pasta X 39/254: /kaggle/input/ortofotosz21/20/407661
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407661'.
#
# Processando pasta X 40/254: /kaggle/input/ortofotosz21/20/407766
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407766'.
#
# Processando pasta X 41/254: /kaggle/input/ortofotosz21/20/407697
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407697'.
#
# Processando pasta X 42/254: /kaggle/input/ortofotosz21/20/407673
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407673'.
#
# Processando pasta X 43/254: /kaggle/input/ortofotosz21/20/407532
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407532'.
#
# Processando pasta X 44/254: /kaggle/input/ortofotosz21/20/407742
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407742'.
#
# Processando pasta X 45/254: /kaggle/input/ortofotosz21/20/407719
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407719'.
#
# Processando pasta X 46/254: /kaggle/input/ortofotosz21/20/407663
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407663'.
#
# Processando pasta X 47/254: /kaggle/input/ortofotosz21/20/407684
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407684'.
#
# Processando pasta X 48/254: /kaggle/input/ortofotosz21/20/407521
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407521'.
#
# Processando pasta X 49/254: /kaggle/input/ortofotosz21/20/407618
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407618'.
#
# Processando pasta X 50/254: /kaggle/input/ortofotosz21/20/407756
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407756'.
#
# Processando pasta X 51/254: /kaggle/input/ortofotosz21/20/407750
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407750'.
#
# Processando pasta X 52/254: /kaggle/input/ortofotosz21/20/407525
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407525'.
#
# Processando pasta X 53/254: /kaggle/input/ortofotosz21/20/407531
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407531'.
#
# Processando pasta X 54/254: /kaggle/input/ortofotosz21/20/407753
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407753'.
#
# Processando pasta X 55/254: /kaggle/input/ortofotosz21/20/407550
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407550'.
#
# Processando pasta X 56/254: /kaggle/input/ortofotosz21/20/407543
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407543'.
#
# Processando pasta X 57/254: /kaggle/input/ortofotosz21/20/407562
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407562'.
#
# Processando pasta X 58/254: /kaggle/input/ortofotosz21/20/407741
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407741'.
#
# Processando pasta X 59/254: /kaggle/input/ortofotosz21/20/407598
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407598'.
#
# Processando pasta X 60/254: /kaggle/input/ortofotosz21/20/407729
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407729'.
#
# Processando pasta X 61/254: /kaggle/input/ortofotosz21/20/407734
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407734'.
#
# Processando pasta X 62/254: /kaggle/input/ortofotosz21/20/407571
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407571'.
#
# Processando pasta X 63/254: /kaggle/input/ortofotosz21/20/407738
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407738'.
#
# Processando pasta X 64/254: /kaggle/input/ortofotosz21/20/407535
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407535'.
#
# Processando pasta X 65/254: /kaggle/input/ortofotosz21/20/407588
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407588'.
#
# Processando pasta X 66/254: /kaggle/input/ortofotosz21/20/407758
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407758'.
#
# Processando pasta X 67/254: /kaggle/input/ortofotosz21/20/407703
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407703'.
#
# Processando pasta X 68/254: /kaggle/input/ortofotosz21/20/407691
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407691'.
#
# Processando pasta X 69/254: /kaggle/input/ortofotosz21/20/407654
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407654'.
#
# Processando pasta X 70/254: /kaggle/input/ortofotosz21/20/407582
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407582'.
#
# Processando pasta X 71/254: /kaggle/input/ortofotosz21/20/407534
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407534'.
#
# Processando pasta X 72/254: /kaggle/input/ortofotosz21/20/407589
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407589'.
#
# Processando pasta X 73/254: /kaggle/input/ortofotosz21/20/407704
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407704'.
#
# Processando pasta X 74/254: /kaggle/input/ortofotosz21/20/407542
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407542'.
#
# Processando pasta X 75/254: /kaggle/input/ortofotosz21/20/407640
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407640'.
#
# Processando pasta X 76/254: /kaggle/input/ortofotosz21/20/407609
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407609'.
#
# Processando pasta X 77/254: /kaggle/input/ortofotosz21/20/407686
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407686'.
#
# Processando pasta X 78/254: /kaggle/input/ortofotosz21/20/407680
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407680'.
#
# Processando pasta X 79/254: /kaggle/input/ortofotosz21/20/407529
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407529'.
#
# Processando pasta X 80/254: /kaggle/input/ortofotosz21/20/407773
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407773'.
#
# Processando pasta X 81/254: /kaggle/input/ortofotosz21/20/407536
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407536'.
#
# Processando pasta X 82/254: /kaggle/input/ortofotosz21/20/407606
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407606'.
#
# Processando pasta X 83/254: /kaggle/input/ortofotosz21/20/407629
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407629'.
#
# Processando pasta X 84/254: /kaggle/input/ortofotosz21/20/407551
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407551'.
#
# Processando pasta X 85/254: /kaggle/input/ortofotosz21/20/407537
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407537'.
#
# Processando pasta X 86/254: /kaggle/input/ortofotosz21/20/407694
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407694'.
#
# Processando pasta X 87/254: /kaggle/input/ortofotosz21/20/407699
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407699'.
#
# Processando pasta X 88/254: /kaggle/input/ortofotosz21/20/407574
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407574'.
#
# Processando pasta X 89/254: /kaggle/input/ortofotosz21/20/407723
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407723'.
#
# Processando pasta X 90/254: /kaggle/input/ortofotosz21/20/407649
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407649'.
#
# Processando pasta X 91/254: /kaggle/input/ortofotosz21/20/407528
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407528'.
#
# Processando pasta X 92/254: /kaggle/input/ortofotosz21/20/407722
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407722'.
#
# Processando pasta X 93/254: /kaggle/input/ortofotosz21/20/407572
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407572'.
#
# Processando pasta X 94/254: /kaggle/input/ortofotosz21/20/407554
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407554'.
#
# Processando pasta X 95/254: /kaggle/input/ortofotosz21/20/407530
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407530'.
#
# Processando pasta X 96/254: /kaggle/input/ortofotosz21/20/407634
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407634'.
#
# Processando pasta X 97/254: /kaggle/input/ortofotosz21/20/407685
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407685'.
#
# Processando pasta X 98/254: /kaggle/input/ortofotosz21/20/407764
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407764'.
#
# Processando pasta X 99/254: /kaggle/input/ortofotosz21/20/407769
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407769'.
#
# Processando pasta X 100/254: /kaggle/input/ortofotosz21/20/407652
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407652'.
#   Salvando dados de 4739 detecções no CSV (total de pastas X processadas: 100)...
#   Dados apensados em: /kaggle/working/zoom20.csv
#
# Processando pasta X 101/254: /kaggle/input/ortofotosz21/20/407580
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407580'.
#
# Processando pasta X 102/254: /kaggle/input/ortofotosz21/20/407770
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407770'.
#
# Processando pasta X 103/254: /kaggle/input/ortofotosz21/20/407653
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407653'.
#
# Processando pasta X 104/254: /kaggle/input/ortofotosz21/20/407711
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407711'.
#
# Processando pasta X 105/254: /kaggle/input/ortofotosz21/20/407688
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407688'.
#
# Processando pasta X 106/254: /kaggle/input/ortofotosz21/20/407569
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407569'.
#
# Processando pasta X 107/254: /kaggle/input/ortofotosz21/20/407611
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407611'.
#
# Processando pasta X 108/254: /kaggle/input/ortofotosz21/20/407763
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407763'.
#
# Processando pasta X 109/254: /kaggle/input/ortofotosz21/20/407615
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407615'.
#
# Processando pasta X 110/254: /kaggle/input/ortofotosz21/20/407644
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407644'.
#
# Processando pasta X 111/254: /kaggle/input/ortofotosz21/20/407736
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407736'.
#
# Processando pasta X 112/254: /kaggle/input/ortofotosz21/20/407724
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407724'.
#
# Processando pasta X 113/254: /kaggle/input/ortofotosz21/20/407748
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407748'.
#
# Processando pasta X 114/254: /kaggle/input/ortofotosz21/20/407712
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407712'.
#
# Processando pasta X 115/254: /kaggle/input/ortofotosz21/20/407632
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407632'.
#
# Processando pasta X 116/254: /kaggle/input/ortofotosz21/20/407679
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407679'.
#
# Processando pasta X 117/254: /kaggle/input/ortofotosz21/20/407674
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407674'.
#
# Processando pasta X 118/254: /kaggle/input/ortofotosz21/20/407672
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407672'.
#
# Processando pasta X 119/254: /kaggle/input/ortofotosz21/20/407655
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407655'.
#
# Processando pasta X 120/254: /kaggle/input/ortofotosz21/20/407728
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407728'.
#
# Processando pasta X 121/254: /kaggle/input/ortofotosz21/20/407650
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407650'.
#
# Processando pasta X 122/254: /kaggle/input/ortofotosz21/20/407692
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407692'.
#
# Processando pasta X 123/254: /kaggle/input/ortofotosz21/20/407771
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407771'.
#
# Processando pasta X 124/254: /kaggle/input/ortofotosz21/20/407669
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407669'.
#
# Processando pasta X 125/254: /kaggle/input/ortofotosz21/20/407646
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407646'.
#
# Processando pasta X 126/254: /kaggle/input/ortofotosz21/20/407754
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407754'.
#
# Processando pasta X 127/254: /kaggle/input/ortofotosz21/20/407733
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407733'.
#
# Processando pasta X 128/254: /kaggle/input/ortofotosz21/20/407555
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407555'.
#
# Processando pasta X 129/254: /kaggle/input/ortofotosz21/20/407760
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407760'.
#
# Processando pasta X 130/254: /kaggle/input/ortofotosz21/20/407768
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407768'.
#
# Processando pasta X 131/254: /kaggle/input/ortofotosz21/20/407590
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407590'.
#
# Processando pasta X 132/254: /kaggle/input/ortofotosz21/20/407681
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407681'.
#
# Processando pasta X 133/254: /kaggle/input/ortofotosz21/20/407689
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407689'.
#
# Processando pasta X 134/254: /kaggle/input/ortofotosz21/20/407631
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407631'.
#
# Processando pasta X 135/254: /kaggle/input/ortofotosz21/20/407746
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407746'.
#
# Processando pasta X 136/254: /kaggle/input/ortofotosz21/20/407714
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407714'.
#
# Processando pasta X 137/254: /kaggle/input/ortofotosz21/20/407556
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407556'.
#
# Processando pasta X 138/254: /kaggle/input/ortofotosz21/20/407658
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407658'.
#
# Processando pasta X 139/254: /kaggle/input/ortofotosz21/20/407567
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407567'.
#
# Processando pasta X 140/254: /kaggle/input/ortofotosz21/20/407700
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407700'.
#
# Processando pasta X 141/254: /kaggle/input/ortofotosz21/20/407603
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407603'.
#
# Processando pasta X 142/254: /kaggle/input/ortofotosz21/20/407565
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407565'.
#
# Processando pasta X 143/254: /kaggle/input/ortofotosz21/20/407616
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407616'.
#
# Processando pasta X 144/254: /kaggle/input/ortofotosz21/20/407717
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407717'.
#
# Processando pasta X 145/254: /kaggle/input/ortofotosz21/20/407642
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407642'.
#
# Processando pasta X 146/254: /kaggle/input/ortofotosz21/20/407676
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407676'.
#
# Processando pasta X 147/254: /kaggle/input/ortofotosz21/20/407547
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407547'.
#
# Processando pasta X 148/254: /kaggle/input/ortofotosz21/20/407707
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407707'.
#
# Processando pasta X 149/254: /kaggle/input/ortofotosz21/20/407581
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407581'.
#
# Processando pasta X 150/254: /kaggle/input/ortofotosz21/20/407559
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407559'.
#
# Processando pasta X 151/254: /kaggle/input/ortofotosz21/20/407664
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407664'.
#
# Processando pasta X 152/254: /kaggle/input/ortofotosz21/20/407739
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407739'.
#
# Processando pasta X 153/254: /kaggle/input/ortofotosz21/20/407683
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407683'.
#
# Processando pasta X 154/254: /kaggle/input/ortofotosz21/20/407548
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407548'.
#
# Processando pasta X 155/254: /kaggle/input/ortofotosz21/20/407705
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407705'.
#
# Processando pasta X 156/254: /kaggle/input/ortofotosz21/20/407549
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407549'.
#
# Processando pasta X 157/254: /kaggle/input/ortofotosz21/20/407625
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407625'.
#
# Processando pasta X 158/254: /kaggle/input/ortofotosz21/20/407638
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407638'.
#
# Processando pasta X 159/254: /kaggle/input/ortofotosz21/20/407597
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407597'.
#
# Processando pasta X 160/254: /kaggle/input/ortofotosz21/20/407698
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407698'.
#
# Processando pasta X 161/254: /kaggle/input/ortofotosz21/20/407592
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407592'.
#
# Processando pasta X 162/254: /kaggle/input/ortofotosz21/20/407539
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407539'.
#
# Processando pasta X 163/254: /kaggle/input/ortofotosz21/20/407759
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407759'.
#
# Processando pasta X 164/254: /kaggle/input/ortofotosz21/20/407557
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407557'.
#
# Processando pasta X 165/254: /kaggle/input/ortofotosz21/20/407595
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407595'.
#
# Processando pasta X 166/254: /kaggle/input/ortofotosz21/20/407522
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407522'.
#
# Processando pasta X 167/254: /kaggle/input/ortofotosz21/20/407628
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407628'.
#
# Processando pasta X 168/254: /kaggle/input/ortofotosz21/20/407560
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407560'.
#
# Processando pasta X 169/254: /kaggle/input/ortofotosz21/20/407721
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407721'.
#
# Processando pasta X 170/254: /kaggle/input/ortofotosz21/20/407636
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407636'.
#
# Processando pasta X 171/254: /kaggle/input/ortofotosz21/20/407713
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407713'.
#
# Processando pasta X 172/254: /kaggle/input/ortofotosz21/20/407612
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407612'.
#
# Processando pasta X 173/254: /kaggle/input/ortofotosz21/20/407716
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407716'.
#
# Processando pasta X 174/254: /kaggle/input/ortofotosz21/20/407731
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407731'.
#
# Processando pasta X 175/254: /kaggle/input/ortofotosz21/20/407682
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407682'.
#
# Processando pasta X 176/254: /kaggle/input/ortofotosz21/20/407648
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407648'.
#
# Processando pasta X 177/254: /kaggle/input/ortofotosz21/20/407608
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407608'.
#
# Processando pasta X 178/254: /kaggle/input/ortofotosz21/20/407570
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407570'.
#
# Processando pasta X 179/254: /kaggle/input/ortofotosz21/20/407701
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407701'.
#
# Processando pasta X 180/254: /kaggle/input/ortofotosz21/20/407660
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407660'.
#
# Processando pasta X 181/254: /kaggle/input/ortofotosz21/20/407540
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407540'.
#
# Processando pasta X 182/254: /kaggle/input/ortofotosz21/20/407726
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407726'.
#
# Processando pasta X 183/254: /kaggle/input/ortofotosz21/20/407575
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407575'.
#
# Processando pasta X 184/254: /kaggle/input/ortofotosz21/20/407568
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407568'.
#
# Processando pasta X 185/254: /kaggle/input/ortofotosz21/20/407577
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407577'.
#
# Processando pasta X 186/254: /kaggle/input/ortofotosz21/20/407635
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407635'.
#
# Processando pasta X 187/254: /kaggle/input/ortofotosz21/20/407730
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407730'.
#
# Processando pasta X 188/254: /kaggle/input/ortofotosz21/20/407666
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407666'.
#
# Processando pasta X 189/254: /kaggle/input/ortofotosz21/20/407576
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407576'.
#
# Processando pasta X 190/254: /kaggle/input/ortofotosz21/20/407718
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407718'.
#
# Processando pasta X 191/254: /kaggle/input/ortofotosz21/20/407747
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407747'.
#
# Processando pasta X 192/254: /kaggle/input/ortofotosz21/20/407627
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407627'.
#
# Processando pasta X 193/254: /kaggle/input/ortofotosz21/20/407523
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407523'.
#
# Processando pasta X 194/254: /kaggle/input/ortofotosz21/20/407613
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407613'.
#
# Processando pasta X 195/254: /kaggle/input/ortofotosz21/20/407693
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407693'.
#
# Processando pasta X 196/254: /kaggle/input/ortofotosz21/20/407621
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407621'.
#
# Processando pasta X 197/254: /kaggle/input/ortofotosz21/20/407520
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407520'.
#
# Processando pasta X 198/254: /kaggle/input/ortofotosz21/20/407585
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407585'.
#
# Processando pasta X 199/254: /kaggle/input/ortofotosz21/20/407670
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407670'.
#
# Processando pasta X 200/254: /kaggle/input/ortofotosz21/20/407675
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407675'.
#   Salvando dados de 6243 detecções no CSV (total de pastas X processadas: 200)...
#   Dados apensados em: /kaggle/working/zoom20.csv
#
# Processando pasta X 201/254: /kaggle/input/ortofotosz21/20/407601
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407601'.
#
# Processando pasta X 202/254: /kaggle/input/ortofotosz21/20/407605
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407605'.
#
# Processando pasta X 203/254: /kaggle/input/ortofotosz21/20/407659
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407659'.
#
# Processando pasta X 204/254: /kaggle/input/ortofotosz21/20/407732
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407732'.
#
# Processando pasta X 205/254: /kaggle/input/ortofotosz21/20/407743
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407743'.
#
# Processando pasta X 206/254: /kaggle/input/ortofotosz21/20/407737
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407737'.
#
# Processando pasta X 207/254: /kaggle/input/ortofotosz21/20/407596
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407596'.
#
# Processando pasta X 208/254: /kaggle/input/ortofotosz21/20/407553
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407553'.
#
# Processando pasta X 209/254: /kaggle/input/ortofotosz21/20/407584
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407584'.
#
# Processando pasta X 210/254: /kaggle/input/ortofotosz21/20/407573
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407573'.
#
# Processando pasta X 211/254: /kaggle/input/ortofotosz21/20/407561
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407561'.
#
# Processando pasta X 212/254: /kaggle/input/ortofotosz21/20/407594
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407594'.
#
# Processando pasta X 213/254: /kaggle/input/ortofotosz21/20/407709
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407709'.
#
# Processando pasta X 214/254: /kaggle/input/ortofotosz21/20/407715
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407715'.
#
# Processando pasta X 215/254: /kaggle/input/ortofotosz21/20/407593
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407593'.
#
# Processando pasta X 216/254: /kaggle/input/ortofotosz21/20/407751
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407751'.
#
# Processando pasta X 217/254: /kaggle/input/ortofotosz21/20/407757
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407757'.
#
# Processando pasta X 218/254: /kaggle/input/ortofotosz21/20/407564
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407564'.
#
# Processando pasta X 219/254: /kaggle/input/ortofotosz21/20/407619
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407619'.
#
# Processando pasta X 220/254: /kaggle/input/ortofotosz21/20/407602
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407602'.
#
# Processando pasta X 221/254: /kaggle/input/ortofotosz21/20/407752
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407752'.
#
# Processando pasta X 222/254: /kaggle/input/ortofotosz21/20/407696
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407696'.
#
# Processando pasta X 223/254: /kaggle/input/ortofotosz21/20/407579
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407579'.
#
# Processando pasta X 224/254: /kaggle/input/ortofotosz21/20/407533
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407533'.
#
# Processando pasta X 225/254: /kaggle/input/ortofotosz21/20/407607
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407607'.
#
# Processando pasta X 226/254: /kaggle/input/ortofotosz21/20/407633
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407633'.
#
# Processando pasta X 227/254: /kaggle/input/ortofotosz21/20/407541
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407541'.
#
# Processando pasta X 228/254: /kaggle/input/ortofotosz21/20/407706
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407706'.
#
# Processando pasta X 229/254: /kaggle/input/ortofotosz21/20/407587
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407587'.
#
# Processando pasta X 230/254: /kaggle/input/ortofotosz21/20/407637
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407637'.
#
# Processando pasta X 231/254: /kaggle/input/ortofotosz21/20/407626
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407626'.
#
# Processando pasta X 232/254: /kaggle/input/ortofotosz21/20/407647
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407647'.
#
# Processando pasta X 233/254: /kaggle/input/ortofotosz21/20/407645
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407645'.
#
# Processando pasta X 234/254: /kaggle/input/ortofotosz21/20/407695
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407695'.
#
# Processando pasta X 235/254: /kaggle/input/ortofotosz21/20/407690
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407690'.
#
# Processando pasta X 236/254: /kaggle/input/ortofotosz21/20/407735
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407735'.
#
# Processando pasta X 237/254: /kaggle/input/ortofotosz21/20/407591
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407591'.
#
# Processando pasta X 238/254: /kaggle/input/ortofotosz21/20/407604
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407604'.
#
# Processando pasta X 239/254: /kaggle/input/ortofotosz21/20/407678
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407678'.
#
# Processando pasta X 240/254: /kaggle/input/ortofotosz21/20/407745
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407745'.
#
# Processando pasta X 241/254: /kaggle/input/ortofotosz21/20/407524
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407524'.
#
# Processando pasta X 242/254: /kaggle/input/ortofotosz21/20/407614
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407614'.
#
# Processando pasta X 243/254: /kaggle/input/ortofotosz21/20/407586
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407586'.
#
# Processando pasta X 244/254: /kaggle/input/ortofotosz21/20/407727
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407727'.
#
# Processando pasta X 245/254: /kaggle/input/ortofotosz21/20/407708
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407708'.
#
# Processando pasta X 246/254: /kaggle/input/ortofotosz21/20/407583
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407583'.
#
# Processando pasta X 247/254: /kaggle/input/ortofotosz21/20/407725
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407725'.
#
# Processando pasta X 248/254: /kaggle/input/ortofotosz21/20/407720
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407720'.
#
# Processando pasta X 249/254: /kaggle/input/ortofotosz21/20/407566
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407566'.
#
# Processando pasta X 250/254: /kaggle/input/ortofotosz21/20/407622
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407622'.
#
# Processando pasta X 251/254: /kaggle/input/ortofotosz21/20/407639
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407639'.
#
# Processando pasta X 252/254: /kaggle/input/ortofotosz21/20/407687
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407687'.
#
# Processando pasta X 253/254: /kaggle/input/ortofotosz21/20/407578
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407578'.
#
# Processando pasta X 254/254: /kaggle/input/ortofotosz21/20/407624
#   Encontradas 367 imagens PNG para processar em '/kaggle/input/ortofotosz21/20/407624'.
#   Salvando dados de 4029 detecções no CSV (total de pastas X processadas: 254)...
#   Dados apensados em: /kaggle/working/zoom20.csv
#
# Processamento de todas as pastas X concluído.
# O arquivo CSV final está salvo em: /kaggle/working/zoom20.csv

# %%
import os

def encontrar_pastas_vazias(diretorio_pai):
    """
    Analisa um diretório pai e retorna uma lista de pastas vazias.

    Args:
        diretorio_pai (str): O caminho para o diretório a ser analisado.

    Returns:
        list: Uma lista contendo os nomes das pastas vazias.
              Retorna None se o diretorio_pai não existir.
    """
    if not os.path.isdir(diretorio_pai):
        print(f"Erro: O diretório '{diretorio_pai}' não foi encontrado.")
        print("Por favor, verifique o caminho no ambiente Kaggle.")
        return None

    pastas_vazias = []
    # Itera sobre os itens no diretorio_pai
    for nome_item in os.listdir(diretorio_pai):
        caminho_completo_item = os.path.join(diretorio_pai, nome_item)
        # Verifica se o item é um diretório
        if os.path.isdir(caminho_completo_item):
            # Verifica se o diretório (subpasta) está vazio
            if not os.listdir(caminho_completo_item):
                pastas_vazias.append(nome_item) # Adiciona o nome da subpasta vazia
    return pastas_vazias

# --- COMO USAR NO KAGGLE ---

# 1. DESCUBRA O CAMINHO CORRETO PARA A PASTA "21":
#    Você pode usar o painel "Data" à direita no editor de notebooks do Kaggle
#    para ver a estrutura dos seus datasets e copiar o caminho.
#    Ou, em uma célula de código, execute: !ls /kaggle/input/ NOME_DO_SEU_DATASET/
#    para listar o conteúdo do seu dataset e encontrar a pasta "21".

#    Exemplos de como o caminho pode se parecer:
#    Se "21" está na raiz de um dataset chamado "meu-dataset-de-imagens":
#    diretorio_principal = '/kaggle/input/meu-dataset-de-imagens/21'

#    Se "21" está dentro de outras pastas no seu dataset, por exemplo:
#    Dataset: "meu-dataset-de-imagens"
#    Estrutura: meu-dataset-de-imagens -> bestmodel -> zoom21 -> 21
#    Então o caminho seria:
#    diretorio_principal = '/kaggle/input/meu-dataset-de-imagens/bestmodel/zoom21/21'

#    Se você criou a pasta "21" em /kaggle/working/:
#    diretorio_principal = '/kaggle/working/21'
#    ou
#    diretorio_principal = '/kaggle/working/Datasets/bestmodel/zoom21/21' # Se você recriou a estrutura

# ⬇️ MODIFIQUE A LINHA ABAIXO COM O CAMINHO CORRETO NO SEU NOTEBOOK KAGGLE ⬇️
diretorio_principal = '/kaggle/input/ortofotosz21/20' # ⬅️ AJUSTE AQUI!

print(f"Analisando o diretório: {diretorio_principal}")

pastas_sem_processamento = encontrar_pastas_vazias(diretorio_principal)

if pastas_sem_processamento is not None:
    if pastas_sem_processamento:
        print("\nPastas (dentro de '21') que parecem estar vazias (sem imagens/arquivos):")
        for pasta in pastas_sem_processamento:
            print(f"- {pasta}")
    else:
        print("\nNenhuma subpasta vazia encontrada dentro de '21'. Todas parecem conter arquivos. 🎉")
# Out:
# Analisando o diretório: /kaggle/input/ortofotosz21/20
#
# Nenhuma subpasta vazia encontrada dentro de '21'. Todas parecem conter arquivos. 🎉
